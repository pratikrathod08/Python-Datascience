# %%
## Ans : 1

# Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5 using Python. Interpret the results.

# we need sample size to answer this question

# %%
## Ans : 2

# we need dobserved frequency for persorm chi square test of goodness

# %% [markdown]
# ## Ans : 3
#
# import pandas as pd
# import scipy.stats as stat
#
# df=pd.DataFrame({'Observed':[20,10,15],'expected':[15,25,20]})
# df
#
# chi2statistics,pvalue=stat.chisquare(df['Observed'],f_exp=df['expected'])

# %%
## Ans : 4

# A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
# smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
# population who smoke.

n=500
smoker=60
alpha=0.5

import statsmodels.stats.proportion as proportion

sample_proportion=smoker/n
print(sample_proportion)

confidence_interval=proportion.proportion_confint(smoker,n,alpha=alpha)
lower_CI,upper_CI=confidence_interval
print(lower_CI,upper_CI)
# Out:
# 0.12
# 0.11019782817112178 0.1298021718288782

# %%
## Ans : 5

# Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.

# we need sample size for calculate CI

# %%
## Ans : 6

# Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
# area corresponding to a chi-square statistic of 15.

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stat

df=10
x=np.linspace(0,30,500) 
pdf=stat.chi2.pdf(x,df)
plt.plot(x,pdf,'y-')

shade_x=np.linspace(15,30)
shade_y=stat.chi2.pdf(shade_x,df)
plt.fill_between(shade_x,shade_y,color='gray',alpha=0.3)

plt.title('chi square distribution')
plt.xlabel('chi square statistics')
plt.ylabel('probability density function')
plt.show()

# %%
## Ans : 7 

import statsmodels.stats.proportion as proportion


# A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
# preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
# prefer Coke.

n=1000
preferred=520
confidence_level=0.99

confidence_interval=proportion.proportion_confint(preferred,n,alpha=1-confidence_level)
lower_CI,higher_CI=confidence_interval
print(lower_CI)
print(higher_CI)
# Out:
# 0.4793051576779699
# 0.5606948423220302

# %%
## Ans : 8

# A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
# 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
# expected frequencies of a fair coin. Use a significance level of 0.05.

h0='observed frequency is match'
h1='observed frequence is not match '

observed=[45,55]
expected=[50,50]
alpha=0.05

chi_square_stats,p_value=stat.chisquare(observed,f_exp=expected)

print(chi_square_stats)
print(p_value)
if p_value > alpha:
    print(h0)
else:
    print(h1)
# Out:
# 1.0
# 0.31731050786291115
# observed frequency is match

# %%
## Ans : 9

#  A study was conducted to determine if there is an association between smoking status (smoker or
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis use the significance level of 0.05.

import pandas as pd
import numpy as np
import scipy.stats as stat

alpha=0.05

h0='there is no significant assosciation between smoking status and lung cancer'
h1='there is significant associate between smoking status and lung cancer'

data=pd.DataFrame({'lung_cancer_yes':[60,30],'lung_cancer_no':[140,170]},index=(['smoker','non_smoker']))
print(data)
new=pd.DataFrame({'lung_cancer_yes':sum(data['lung_cancer_yes']),'lung_cancer_no':sum(data['lung_cancer_no'])},index=(['total']))
print(new)
data=pd.concat([data,new],axis=0)
data['row_total']=data['lung_cancer_yes']+data['lung_cancer_no']
data_df=pd.DataFrame(data)
print(data)
data_df.head()

expected=np.outer(data['row_total'][0:2],data.loc['total'][0:2])/400
print(expected)

expected_df=pd.DataFrame(expected)
expected_df.head()

expected_df.columns=['lung_cancer_yes','lung_cancer_no']
expected_df.index=['smoker','non_smoker']

observed_df=data_df.iloc[0:2,0:2]

chi_square_stat=(((observed_df-expected_df)**2)/expected_df).sum().sum()
print(chi_square_stat)

df=(len(observed_df.columns)-1)*(len(observed_df)-1)
df

critical_value=stat.chi2.ppf(q=0.95,df=df)
print(critical_value)

p_value=1-stat.chi2.cdf(x=chi_square_stat,df=df)
print(p_value)

if p_value < alpha:
    print('we reject null hypothesis')
else:
    print(' we fail to reject null hypothesis')
    
if chi_square_stat > critical_value:
    print('reject the null hypothesis ')
else:
    print('accept the null hypothesis')
    
    
conclusion=h1
print(h1)

# %%
## Ans : 9

#  A study was conducted to determine if there is an association between smoking status (smoker or
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis use the significance level of 0.05.

import pandas as pd
import numpy as np
import scipy.stats as stat
alpha=0.05

h0='there is no significant assosciation between smoking status and lung cancer'
h1='there is significant associate between smoking status and lung cancer'

data=pd.DataFrame({'lung_cancer_yes':[60,30],'lung_cancer_no':[140,170]},index=(['smoker','non_smoker']))
print(data)
new=pd.DataFrame({'lung_cancer_yes':sum(data['lung_cancer_yes']),'lung_cancer_no':sum(data['lung_cancer_no'])},index=(['total']))
print(new)
data=pd.concat([data,new],axis=0)
data['row_total']=data['lung_cancer_yes']+data['lung_cancer_no']
data_df=pd.DataFrame(data)
print(data)
data_df.head()

expected=np.outer(data['row_total'][0:2],data.loc['total'][0:2])/400
print(expected)

expected_df=pd.DataFrame(expected)
expected_df.head()

expected_df.columns=['lung_cancer_yes','lung_cancer_no']
expected_df.index=['smoker','non_smoker']

observed_df=data_df.iloc[0:2,0:2]

chi_square_stat=(((observed_df-expected_df)**2)/expected_df).sum().sum()
print(chi_square_stat)

df=(len(observed_df.columns)-1)*(len(observed_df)-1)
df

critical_value=stat.chi2.ppf(q=0.95,df=df)
critical_value

p_value=1-stat.chi2.cdf(x=chi_square_stat,df=df)
print(p_value)

if p_value > alpha:
    print(h0)
else:
    print(h1)
# Out:
#             lung_cancer_yes  lung_cancer_no
# smoker                   60             140
# non_smoker               30             170
#        lung_cancer_yes  lung_cancer_no
# total               90             310
#             lung_cancer_yes  lung_cancer_no  row_total
# smoker                   60             140        200
# non_smoker               30             170        200
# total                    90             310        400
# [[ 45. 155.]
#  [ 45. 155.]]
# 12.903225806451612
# 0.0003280163150135573
# there is significant associate between smoking status and lung cancer

# %%
## Ans : 10

# A study was conducted to determine if the proportion of people who prefer milk chocolate, dark
# chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from
# the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the
# contingency table below. Conduct a chi-square test for independence to determine if there is a significant
# association between chocolate preference and country of origin  use significance level=0.01.


import pandas as pd
import numpy as np
import scipy.stats as stat
from scipy.stats.contingency import expected_freq

alpha=0.01

observed=pd.DataFrame({'Milk_chocolate':[200,225],'Dark_chocolate':[150,175],'White_chocolate':[150,100]},index=['U.S','U.K'])
col_sum=pd.DataFrame({'Milk_chocolate':sum(observed['Milk_chocolate']),'Dark_chocolate':sum(observed['Dark_chocolate']),'White_chocolate':sum(observed['White_chocolate'])},index=['col_sum'])
observed_sum=pd.concat([observed,col_sum])
observed_sum['row_sum']=observed_sum['Milk_chocolate']+observed_sum['Dark_chocolate']+observed_sum['White_chocolate']
observed_sum

h0= "there is no significance association between chocolate preference and country of origin"
h1="there is a significance association between chocolate preference and country of origin"


expected=np.outer(observed_sum['row_sum'][0:2],observed_sum.loc['col_sum'][0:3])/1000
print(expected)
expected=pd.DataFrame(expected)
expected1=expected_freq(observed)   # we can get expected freq like that .
expected.head()
expected.columns=([observed.columns])
expected.index=([observed.index])
expected

chisquare_test_statistics,p_value=stat.chisquare(observed,expected)
chi_square_stat=sum(chisquare_test_statistics)
chi_square_stat
# print(p_value)        # we can not use this p value because by above formula we only ger single array p value 

df=(len(observed.columns)-1)*(len(observed)-1)
print(df)

p_value1=1-stat.chi2.cdf(x=chi_square_stat,df=df)
print(p_value1)

critical_value=stat.chi2.ppf(q=0.99,df=df)
critical_value

if p_value1 < alpha:
    print('we reject null hypothesis')
else:
    print(' we fail to reject null hypothesis')
    
if chi_square_stat > critical_value:
    print('reject the null hypothesis ')
else:
    print('accept the null hypothesis')

        
    
conclusion=h1
print(h1)
# Out:
# [[212.5 162.5 125. ]
#  [212.5 162.5 125. ]]
# 2
# 0.00123481689977456
# we reject null hypothesis
# reject the null hypothesis
# there is a significance association between chocolate preference and country of origin

# %%
## Ans : 10

# A study was conducted to determine if the proportion of people who prefer milk chocolate, dark
# chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from
# the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the
# contingency table below. Conduct a chi-square test for independence to determine if there is a significant
# association between chocolate preference and country of origin  use significance level=0.01.


import pandas as pd
import numpy as np
import scipy.stats as stat
from scipy.stats.contingency import expected_freq

alpha=0.01

observed=pd.DataFrame({'Milk_chocolate':[200,225],'Dark_chocolate':[150,175],'White_chocolate':[150,100]},index=['U.S','U.K'])
col_sum=pd.DataFrame({'Milk_chocolate':sum(observed['Milk_chocolate']),'Dark_chocolate':sum(observed['Dark_chocolate']),'White_chocolate':sum(observed['White_chocolate'])},index=['col_sum'])
observed_sum=pd.concat([observed,col_sum])
observed_sum['row_sum']=observed_sum['Milk_chocolate']+observed_sum['Dark_chocolate']+observed_sum['White_chocolate']
observed_sum

h0= "there is no significance association between chocolate preference and country of origin"
h1="there is a significance association between chocolate preference and country of origin"


expected=np.outer(observed_sum['row_sum'][0:2],observed_sum.loc['col_sum'][0:3])/1000
print(expected)
expected=pd.DataFrame(expected)
expected1=expected_freq(observed)   # we can get expected freq like that .
expected.head()
expected.columns=([observed.columns])
expected.index=([observed.index])
expected

chisquare_test_statistics,p_value=stat.chisquare(observed,expected)
chi_square_stat=sum(chisquare_test_statistics)
chi_square_stat
# print(p_value)        # we can not use this p value because by above formula we only ger single array p value 

df=(len(observed.columns)-1)*(len(observed)-1)
print(df)

p_value1=1-stat.chi2.cdf(x=chi_square_stat,df=df)
print(p_value1)

critical_value=stat.chi2.ppf(q=0.99,df=df)
critical_value

if p_value1 > alpha:
    print(h0)
else:
    print(h1)
# Out:
# [[212.5 162.5 125. ]
#  [212.5 162.5 125. ]]
# 2
# 0.00123481689977456
# there is a significance association between chocolate preference and country of origin

# %%
## Ans : 11

# A random sample of 30 people was selected from a population with an unknown mean and standard
# deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.
# Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a
# significance level of 0.05.

n=30
sample_mean=72
sample_std=10
alpha=0.05
df=n-1
population_mean=0

h0='there is no significant diffrence from 70'
h1='there is significant diffrence from 70'

import scipy.stats as stat
import numpy as np

critical_value=stat.t.ppf(1-alpha/2,df=df)
print('critical value :',critical_value)

t_score=(sample_mean-population_mean)/(sample_std/np.sqrt(n))
print('T score is :',t_score)

p_value=stat.t.sf(x=abs(t_score),df=df)
print('p value : ',p_value)

if p_value < alpha:
    print('we reject null hypothesis')
else:
    print('we fail to reject null hypothesis')
    
print('conclusion : ',h0)
# Out:
# critical value : 2.045229642132703
# T score is : 39.436024140371956
# p value :  4.75603165751559e-27
# we reject null hypothesis
# conclusion :  there is no significant diffrence from 70
